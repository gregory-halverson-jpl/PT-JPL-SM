# %% [markdown]
# # PT-JPL-SM Sensitivity Analysis with ECOv002 Cal-Val
#
# This notebook performs a sensitivity analysis of the PT-JPL-SM model using ECOSTRESS Collection 2 Cal-Val data. It loads input data, processes it through the PT-JPL-SM model, and visualizes the impact of input perturbations on latent heat flux. The notebook also generates figures for publication and explores the relationship between surface temperature and latent heat flux.

# %% [markdown]
# ## Import Required Libraries and Functions
#
# This cell imports all necessary libraries and functions for data processing, model execution, statistical analysis, and plotting. It includes custom modules for the PT-JPL-SM model, sensitivity analysis, and net radiation calculations, as well as standard scientific Python libraries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

# %%
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table
from PTJPLSM import process_PTJPLSM_table, load_ECOv002_calval_PTJPLSM_inputs
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Set Normalization Function
#
# This cell assigns the normalization function used to compare perturbed model outputs to the unperturbed baseline. The function `divide_absolute_by_unperturbed` is used for normalization in the sensitivity analysis.

# %%
normalization_function = divide_absolute_by_unperturbed

# %% [markdown]
# ## Load and Filter Input Data
#
# This cell loads the ECOSTRESS Cal-Val input data using a custom loader function and filters out rows where `fAPARmax` is zero. The resulting DataFrame is displayed for inspection.

# %%
input_df = load_ECOv002_calval_PTJPLSM_inputs()
input_df = input_df[input_df.fAPARmax != 0]
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C  \
# 0     392.851840   307.021970  487.383423         118.916280  ...  31.95
# 1     640.118470   375.089300  106.825577         167.919460  ...  31.19
# 2     625.661700   284.686250         NaN         132.936340  ...  30.91
# 3     624.254330   251.414490  178.827545         141.132420  ...  28.65
# 4     511.082180   228.520170  154.791626         114.809410  ...  30.03
# ...          ...          ...         ...                ...  ...    ...
# 1060   81.645230    15.282976         NaN          56.385185  ...   5.63
# 1061   65.469320    22.186659         NaN          40.509410  ...  20.13
# 1062  118.777240    55.343586         NaN          52.403820  ...  28.79
# 1063  126.490524    40.434025         NaN          57.769722  ...  17.57
# 1064  271.749480   119.763630  190.823303         122.092445  ...  41.61
#
#            Ta_C   SWin_Wm2  emissivity  \
# 0     32.658920  545.51056       0.948
# 1     24.227982  848.34390       0.952
# 2     26.178862  838.81160       0.972
# 3     22.527096  851.72480       0.974
# 4     23.280691  702.55160       0.960
# ...         ...        ...         ...
# 1060   3.815752  286.84660       0.980
# 1061  19.266186  290.87400       0.976
# 1062  32.110336  352.19530       0.976
# 1063  10.464681  420.67880       0.976
# 1064  30.316103  781.84110       0.978
#
#                                               name  Topt_C  fAPARmax  \
# 0                                    NC_Clearcut#3   10.09    0.4659
# 1     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 2     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 3     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 4     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# ...                                            ...     ...       ...
# 1060     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1061     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1062     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1063     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1064     NEON Klemme Range Research Station (OAES)    7.99    0.3387
#
#       canopy_height_meters  field_capacity  wilting_point
# 0                20.642902            0.24           0.11
# 1                 0.000000            0.31           0.14
# 2                 0.000000            0.31           0.14
# 3                 0.000000            0.31           0.14
# 4                 0.000000            0.31           0.14
# ...                    ...             ...            ...
# 1060              0.000000            0.28           0.13
# 1061              0.000000            0.28           0.13
# 1062              0.000000            0.28           0.13
# 1063              0.000000            0.28           0.13
# 1064              0.000000            0.28           0.13
#
# [1065 rows x 83 columns]

# %% [markdown]
# ## Check Minimum fAPARmax Value
#
# This cell computes the minimum value of `fAPARmax` in the filtered input data to verify the filtering step and ensure no zero values remain.

# %%
np.nanmin(input_df.fAPARmax)
# Out:
# np.float64(0.2331)

# %% [markdown]
# ## Define Processing Function for Model Table
#
# This cell defines a helper function that processes the input DataFrame through the Verma net radiation calculation and then the PT-JPL-SM model. This function is used in later analysis steps.

# %%
def process_verma_PTJPLSM_table(input_df: pd.DataFrame) -> pd.DataFrame:
    return process_PTJPLSM_table(verma_net_radiation_table(input_df), upscale_to_daylight=True)

# %% [markdown]
# ## Process Input Data Through Model
#
# This cell applies the processing function to the filtered input data, running it through the Verma net radiation and PT-JPL-SM model, and displays the resulting DataFrame.

# %%
processed = process_verma_PTJPLSM_table(input_df)
processed
# Out:
# [2025-08-20 18:15:25 INFO] starting Verma net radiation processing
# [2025-08-20 18:15:25 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.722 max: 443.569 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] Verma net radiation processing complete in 0.07 seconds
# [2025-08-20 18:15:25 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:15:25 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:15:25 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:15:25 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:15:25 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:15:25 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:15:25 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:15:25 INFO] variable Topt_C min: 0.000 mean: 8.174 max: 23.210 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable fAPARmax min: 0.233 mean: 0.382 max: 0.624 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:15:25 INFO] variable Ta_C min: -14.605 mean: 22.322 max: 39.710 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given relative humidity (RH)
# [2025-08-20 18:15:25 INFO] variable RH min: 0.273 mean: 0.427 max: 0.984 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given soil moisture (SM)
# [2025-08-20 18:15:25 INFO] variable soil_moisture min: 0.000 mean: 0.168 max: 0.897 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given field capacity
# [2025-08-20 18:15:25 INFO] variable field_capacity min: 0.190 mean: 0.283 max: 0.390 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given wilting point
# [2025-08-20 18:15:25 INFO] variable wilting_point min: 0.040 mean: 0.121 max: 0.290 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] using given canopy height
# [2025-08-20 18:15:25 INFO] variable canopy_height_meters min: 0.000 mean: 6.044 max: 30.192 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:15:25 INFO] starting Verma net radiation processing
# [2025-08-20 18:15:25 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:15:25 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:15:25 INFO] variable G min: 0.000 mean: 52.277 max: 165.530 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable fwet min: 0.006 mean: 0.054 max: 0.936 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable fREW min: 0.000 mean: 0.459 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Topt_C min: 0.000 mean: 8.174 max: 23.210 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Topt_C min: 0.100 mean: 22.786 max: 39.710 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable epsilon min: 0.198 mean: 0.701 max: 0.854 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 224.178 max: 601.557 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable LE_soil_Wm2 min: 0.000 mean: 50.764 max: 308.842 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 198.646 max: 743.370 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable PET min: 0.000 mean: 331.837 max: 762.248 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable fTRM min: 0.000 mean: 0.810 max: 1.000 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 125.439 max: 518.164 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable LE_interception_Wm2 min: 0.000 mean: 10.555 max: 100.607 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable LE_Wm2 min: 0.000 mean: 186.758 max: 618.534 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] started daylight ET upscaling
# [2025-08-20 18:15:25 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 257.722 max: 443.569 nan: 0.00% (nan)
# [2025-08-20 18:15:25 INFO] variable EF min: 0.000 mean: 0.478 max: 0.994 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 127.699 max: 349.908 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] variable ET_daylight_kg min: 0.000 mean: 2.520 max: 7.514 nan: 0.19% (nan)
# [2025-08-20 18:15:25 INFO] completed daylight ET upscaling (elapsed: 0.02 seconds)
# [2025-08-20 18:15:25 INFO] PT-JPL-SM model run complete (elapsed: 0.12 seconds)
# [2025-08-20 18:15:25 INFO] PT-JPL-SM table processing complete
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  \
# 0     392.851840   307.021970  487.383423         118.916280  ...
# 1     640.118470   375.089300  106.825577         167.919460  ...
# 2     625.661700   284.686250         NaN         132.936340  ...
# 3     624.254330   251.414490  178.827545         141.132420  ...
# 4     511.082180   228.520170  154.791626         114.809410  ...
# ...          ...          ...         ...                ...  ...
# 1060   81.645230    15.282976         NaN          56.385185  ...
# 1061   65.469320    22.186659         NaN          40.509410  ...
# 1062  118.777240    55.343586         NaN          52.403820  ...
# 1063  126.490524    40.434025         NaN          57.769722  ...
# 1064  271.749480   119.763630  190.823303         122.092445  ...
#
#       Rn_soil_Wm2  LE_soil_Wm2  Rn_canopy_Wm2     PET_Wm2  LE_canopy_Wm2  \
# 0      108.445418    58.201498     286.941176  349.932890     226.051334
# 1      242.327021   148.708756     399.409026  517.083672     222.315394
# 2      265.452689   171.730760     388.886290  539.879902      96.551225
# 3      220.223334   134.990066     458.330042  547.373133     108.049874
# 4      163.457363    95.318041     353.223153  416.712815     118.816031
# ...           ...          ...            ...         ...            ...
# 1060   120.709633     1.660663      41.541526   91.824890      13.658025
# 1061   132.038087     2.481284      34.328190  128.742933      19.782974
# 1062   186.580017     2.096448      69.932313  225.364587      58.572453
# 1063   179.019182     1.670621      67.505054  160.182155      39.163293
# 1064   396.978125     6.298751     145.622651  435.565400     112.621752
#
#       LE_interception_Wm2      LE_Wm2        EF  LE_daylight_Wm2  \
# 0               28.734376  312.987207  0.909352       214.959059
# 1               16.280228  387.304378  0.690818       229.941542
# 2               54.990754  323.272740  0.566856       191.449165
# 3               62.517459  305.557399  0.502264       184.319467
# 4               34.312196  248.446268  0.542482       164.409776
# ...                   ...         ...       ...              ...
# 1060             0.591490   15.910178  0.100587        12.450232
# 1061             0.730644   22.994902  0.152377        27.132059
# 1062             0.958892   61.627793  0.276572        72.706319
# 1063             0.708102   41.542015  0.183191        38.889062
# 1064             3.131581  122.052084  0.278325        79.388002
#
#       ET_daylight_kg
# 0           3.691328
# 1           5.083482
# 2           4.228934
# 3           4.065880
# 4           3.624539
# ...              ...
# 1060        0.176834
# 1061        0.484122
# 1062        1.367768
# 1063        0.735651
# 1064        1.526165
#
# [1065 rows x 100 columns]

# %% [markdown]
# ## Plot Unperturbed Comparison of Surface Temperature to Latent Heat Flux
#
# This cell creates a scatter plot comparing ECOSTRESS surface temperature to PT-JPL-SM latent heat flux for the unperturbed data. The plot is saved as both JPEG and SVG files for publication or further analysis.

# %%
plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
plt.scatter(x=processed.ST_C, y=processed.ET_daylight_kg, color='black', s=10, zorder=5)
plt.grid(True, zorder=0)
plt.xlabel("ECOSTRESS Surface Temperature (°C)")
plt.ylabel("PT-JPL-SM Daily ET (mm/day)")
plt.title("Unperturbed Comparison\nof ECOSTRESS Surface Temperature\nto PT-JPL-SM Evapotranspiration")

plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL-SM Evapotranspiration.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL-SM Evapotranspiration.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Further Filter Input Data and Check Temperature Range
#
# This cell applies additional filters to the input data, ensuring only valid `fAPARmax` and `NDVI` values are included. It also checks the minimum and maximum surface temperature values in the filtered dataset.

# %%
# input_df = pd.read_csv(input_filename)
input_df = load_ECOv002_calval_PTJPLSM_inputs()

if "Ta" in input_df and "Ta_C" not in input_df:
    # input_df.rename({"Ta": "Ta_C"}, inplace=True)
    input_df["Ta_C"] = input_df["Ta"]

input_df = input_df[input_df.fAPARmax.apply(lambda fAPARmax: fAPARmax > 0.001)]
input_df = input_df[input_df.NDVI.apply(lambda NDVI: NDVI > 0.05)]

np.nanmin(input_df.ST_C), np.nanmax(input_df.ST_C)
# Out:
# (np.float64(-13.189999999999998), np.float64(86.11000000000001))

# %% [markdown]
# ## Check Number of Valid Input Rows
#
# This cell displays the number of rows remaining in the input DataFrame after all filtering steps, confirming the size of the dataset used for analysis.

# %%
len(input_df)
# Out:
# 1063

# %%
input_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'vegetation', 'climate', 'STICinst', 'BESSinst',
#        'MOD16inst', 'PTJPLSMinst', 'ETinst', 'ETinstUncertainty', 'PET', 'Rn',
#        'ESI', 'RH', 'Ta', 'LST', 'SM', 'NDVI', 'NDVI-UQ', 'albedo',
#        'albedo-UQ', 'LST_err', 'view_zenith', 'Rg', 'EmisWB', 'time_utc',
#        'solar_time', 'solar_hour', 'local_time', 'LE', 'LE_filt', 'LEcorr25',
#        'LEcorr50', 'LEcorr75', 'LEcorr_ann', 'H_filt', 'Hcorr25', 'Hcorr50',
#        'Hcorr75', 'Hcorr_ann', 'NETRAD_filt', 'G_filt', 'SM_surf', 'SM_rz',
#        'AirTempC', 'SW_IN', 'RH_percentage', 'ESIrn_STIC', 'ESIrn_PTJPLSM',
#        'ESIrn_MOD16', 'ESIrn_BESS', 'ESIrn_Unc_ECO', 'ESIrn_LEcorr50', 'JET',
#        'eco_time_utc', 'Site Name', 'Date-Time', 'Site ID', 'Name', 'Lat',
#        'Long', 'Elev', 'Clim', 'Veg', 'MAT', 'MAP', 'StartDate', 'EndDate',
#        'LE_count', 'closure_ratio', 'geometry', 'time_UTC', 'ST_K', 'ST_C',
#        'Ta_C', 'SWin_Wm2', 'emissivity', 'name', 'Topt_C', 'fAPARmax',
#        'canopy_height_meters', 'field_capacity', 'wilting_point'],
#       dtype='object')

# %%
input_df["SWin_Wm2"] = input_df["SW_IN"]
input_df["emissivity"] = input_df["EmisWB"]

# %%
# Ensure all relevant columns are numeric before sensitivity analysis
for col in ["albedo", "SWin_Wm2", "ST_C", "emissivity", "Ta_C", "RH"]:
    if col in input_df.columns:
        input_df[col] = pd.to_numeric(input_df[col], errors="coerce")
# Drop rows with NaN in any relevant column
input_df = input_df.dropna(subset=["albedo", "SWin_Wm2", "ST_C", "emissivity", "Ta_C", "RH"])

# %%
input_df = input_df.dropna()
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  MOD16inst  \
# 15            15  US-xAB        ENF     Csb  141.635670  168.24043  402.81810
# 17            17  US-xAB        ENF     Csb    1.881266  163.94730  301.40400
# 18            18  US-xAB        ENF     Csb    3.135606  246.87700  614.51480
# 19            19  US-xAB        ENF     Csb  311.482820  290.73126  672.27510
# 20            20  US-xAB        ENF     Csb   51.920338   95.28810  116.67136
# ...          ...     ...        ...     ...         ...        ...        ...
# 992          992  US-xML        DBF     Dfb  417.831120  706.93066  523.92740
# 994          994  US-xML        DBF     Dfb  161.558200  306.15277  420.44678
# 1001        1001  US-UiB        CRO     Dfa   93.876100  251.38747  238.71077
# 1020        1020  US-ARM        CRO     Cfa   80.255005    0.00000  180.10085
# 1021        1021  US-ARM        CRO     Cfa  126.236190    0.00000  199.79102
#
#       PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C       Ta_C  \
# 15      159.71700  139.016083         107.183200  ...  20.01  15.849697
# 17      179.13661  131.273636         106.525215  ...  14.63  14.842857
# 18      405.50497  366.056641         222.890230  ...  24.97  21.549250
# 19      478.82382  439.821228         153.787670  ...  33.03  26.457556
# 20       73.20884  232.693512          24.038680  ...  10.93  12.976667
# ...           ...         ...                ...  ...    ...        ...
# 992     310.69684  356.174072         148.624050  ...  16.47  16.969240
# 994     206.48576  237.659103          98.727560  ...  13.17  14.792879
# 1001    198.90399  106.316444          67.694800  ...  25.93   9.609989
# 1020    211.28325  164.581390          84.672410  ...  31.85  22.611721
# 1021    232.13673  281.860535          89.163790  ...  35.23  23.101131
#
#       SWin_Wm2  emissivity                                          name  \
# 15     574.985       0.972                         NEON Abby Road (ABBY)
# 17     386.290       0.978                         NEON Abby Road (ABBY)
# 18     876.800       0.976                         NEON Abby Road (ABBY)
# 19     948.235       0.974                         NEON Abby Road (ABBY)
# 20      98.315       0.954                         NEON Abby Road (ABBY)
# ...        ...         ...                                           ...
# 992    735.490       0.972  NEON Mountain Lake Biological Station (MLBS)
# 994    554.470       0.972  NEON Mountain Lake Biological Station (MLBS)
# 1001  1008.000       0.946             University of Illinois Miscanthus
# 1020   701.520       0.958        ARM Southern Great Plains site- Lamont
# 1021   749.332       0.952        ARM Southern Great Plains site- Lamont
#
#       Topt_C  fAPARmax  canopy_height_meters  field_capacity  wilting_point
# 15      6.69    0.6040              6.244725            0.33           0.16
# 17      6.69    0.6040              6.244725            0.33           0.16
# 18      6.69    0.6040              6.244725            0.33           0.16
# 19      6.69    0.6040              6.244725            0.33           0.16
# 20      6.69    0.6040              6.244725            0.33           0.16
# ...      ...       ...                   ...             ...            ...
# 992     2.66    0.5404             23.197309            0.34           0.14
# 994     2.66    0.5404             23.197309            0.34           0.14
# 1001    2.58    0.4060              0.000000            0.32           0.14
# 1020    8.48    0.4017              0.000000            0.29           0.12
# 1021    8.48    0.4017              0.000000            0.29           0.12
#
# [295 rows x 83 columns]

# %% [markdown]
# ## Run Perturbed Model Analysis
#
# This cell sets up the input and output variables for the sensitivity analysis and runs the `perturbed_run` function, which perturbs the input variable and observes the effect on the output variable using the PT-JPL-SM model. The results are displayed for further analysis.

# %%
input_variable = "ST_C"
output_variable = "ET_daylight_kg"

results = perturbed_run(
    input_df=input_df, 
    input_variable=input_variable, 
    output_variable=output_variable, 
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

results
# Out:
# [2025-08-20 18:17:03 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:03 INFO] calculating standard deviation of input variable: ST_C
# [2025-08-20 18:17:03 INFO] input variable ST_C standard deviation: 11.932784328125438
# [2025-08-20 18:17:03 INFO] starting forward process
# [2025-08-20 18:17:03 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:03 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:03 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:03 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:03 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:03 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:03 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:03 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:03 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:03 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:03 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:03 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:03 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given field capacity
# [2025-08-20 18:17:03 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given wilting point
# [2025-08-20 18:17:03 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] using given canopy height
# [2025-08-20 18:17:03 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:03 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:03 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-08-20 18:17:03 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:03 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] started daylight ET upscaling
# [2025-08-20 18:17:03 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:03 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:03 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-08-20 18:17:03 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:03 INFO] forward process completed
# [2025-08-20 18:17:03 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:03 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:03 INFO] starting input perturbation generation
# [2025-08-20 18:17:03 INFO] input perturbation generation completed
# [2025-08-20 18:17:03 INFO] generating control group
# [2025-08-20 18:17:03 INFO] normalizing input perturbations
# [2025-08-20 18:17:03 INFO] applying perturbations
# [2025-08-20 18:17:03 INFO] starting forward process for perturbed input
# [2025-08-20 18:17:04 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:04 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LWout_Wm2 min: 196.393 mean: 485.798 max: 985.622 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Rn_Wm2 min: 0.000 mean: 500.477 max: 1010.483 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 304.120 max: 562.397 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] Verma net radiation processing complete in 0.34 seconds
# [2025-08-20 18:17:04 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:04 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:04 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:04 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:04 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:04 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:04 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:04 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:04 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:04 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:04 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given field capacity
# [2025-08-20 18:17:04 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given wilting point
# [2025-08-20 18:17:04 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] using given canopy height
# [2025-08-20 18:17:04 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:04 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:04 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LWout_Wm2 min: 196.393 mean: 485.798 max: 985.622 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Rn_Wm2 min: 0.000 mean: 500.477 max: 1010.483 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:04 INFO] variable Rn_Wm2 min: 0.000 mean: 500.477 max: 1010.483 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:04 INFO] variable G min: 0.000 mean: 71.000 max: 200.682 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 323.837 max: 838.370 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LE_soil_Wm2 min: 0.000 mean: 52.773 max: 513.785 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 176.640 max: 855.179 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable PET min: 0.000 mean: 389.389 max: 960.551 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable fTRM min: 0.047 mean: 0.832 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 121.170 max: 608.329 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LE_interception_Wm2 min: 0.000 mean: 6.583 max: 122.560 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LE_Wm2 min: 0.000 mean: 180.526 max: 833.003 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] started daylight ET upscaling
# [2025-08-20 18:17:04 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 304.120 max: 562.397 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable EF min: 0.000 mean: 0.403 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:04 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 124.751 max: 497.785 nan: 0.00% (nan)
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
# [2025-08-20 18:17:05 INFO] variable ET_daylight_kg min: 0.000 mean: 2.458 max: 11.084 nan: 0.00% (nan)
# [2025-08-20 18:17:05 INFO] completed daylight ET upscaling (elapsed: 0.29 seconds)
# [2025-08-20 18:17:05 INFO] PT-JPL-SM model run complete (elapsed: 0.34 seconds)
# [2025-08-20 18:17:05 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:05 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:05 INFO] normalizing output perturbations
# [2025-08-20 18:17:05 INFO] Monte Carlo run complete
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 0               ST_C  ET_daylight_kg             20.01          -16.977726
# 1               ST_C  ET_daylight_kg             20.01            1.258950
# 2               ST_C  ET_daylight_kg             20.01           10.909613
# 3               ST_C  ET_daylight_kg             20.01           18.400776
# 4               ST_C  ET_daylight_kg             20.01            0.368730
# ...              ...             ...               ...                 ...
# 29495           ST_C  ET_daylight_kg             35.23          -13.487216
# 29496           ST_C  ET_daylight_kg             35.23            5.864959
# 29497           ST_C  ET_daylight_kg             35.23           -0.439688
# 29498           ST_C  ET_daylight_kg             35.23          -15.287193
# 29499           ST_C  ET_daylight_kg             35.23          -22.638094
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 0                    0.848462        3.032274           2.734929
# 1                    0.062916        21.26895           2.734929
# 2                    0.545208       30.919613           2.734929
# 3                    0.919579       38.410776           2.734929
# 4                    0.018427        20.37873           2.734929
# ...                       ...             ...                ...
# 29495                0.382833       21.742784           3.783944
# 29496                0.166476       41.094959           3.783944
# 29497                0.012481       34.790312           3.783944
# 29498                0.433925       19.942807           3.783944
# 29499                0.642580       12.591906           3.783944
#
#       output_perturbation output_perturbation_std  output_perturbed
# 0                0.648291                0.237041          3.383220
# 1               -0.051019                0.018655          2.683909
# 2               -0.455441                0.166528          2.279488
# 3               -0.785321                0.287145          1.949607
# 4               -0.014901                0.005448          2.720028
# ...                   ...                     ...               ...
# 29495            0.626556                0.165583          4.410500
# 29496           -0.295836                0.078182          3.488108
# 29497            0.021599                0.005708          3.805543
# 29498            0.704656                0.186223          4.488599
# 29499            1.010541                 0.26706          4.794485
#
# [29500 rows x 10 columns]

# %% [markdown]
# ## Filter Out NaN Results
#
# This cell removes any rows with missing values from the perturbed results to ensure only valid data points are used in subsequent analysis and plotting.

# %%
filtered_results = results.dropna()
filtered_results
# Out:
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 0               ST_C  ET_daylight_kg             20.01          -16.977726
# 1               ST_C  ET_daylight_kg             20.01            1.258950
# 2               ST_C  ET_daylight_kg             20.01           10.909613
# 3               ST_C  ET_daylight_kg             20.01           18.400776
# 4               ST_C  ET_daylight_kg             20.01            0.368730
# ...              ...             ...               ...                 ...
# 29495           ST_C  ET_daylight_kg             35.23          -13.487216
# 29496           ST_C  ET_daylight_kg             35.23            5.864959
# 29497           ST_C  ET_daylight_kg             35.23           -0.439688
# 29498           ST_C  ET_daylight_kg             35.23          -15.287193
# 29499           ST_C  ET_daylight_kg             35.23          -22.638094
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 0                    0.848462        3.032274           2.734929
# 1                    0.062916        21.26895           2.734929
# 2                    0.545208       30.919613           2.734929
# 3                    0.919579       38.410776           2.734929
# 4                    0.018427        20.37873           2.734929
# ...                       ...             ...                ...
# 29495                0.382833       21.742784           3.783944
# 29496                0.166476       41.094959           3.783944
# 29497                0.012481       34.790312           3.783944
# 29498                0.433925       19.942807           3.783944
# 29499                0.642580       12.591906           3.783944
#
#       output_perturbation output_perturbation_std  output_perturbed
# 0                0.648291                0.237041          3.383220
# 1               -0.051019                0.018655          2.683909
# 2               -0.455441                0.166528          2.279488
# 3               -0.785321                0.287145          1.949607
# 4               -0.014901                0.005448          2.720028
# ...                   ...                     ...               ...
# 29495            0.626556                0.165583          4.410500
# 29496           -0.295836                0.078182          3.488108
# 29497            0.021599                0.005708          3.805543
# 29498            0.704656                0.186223          4.488599
# 29499            1.010541                 0.26706          4.794485
#
# [29500 rows x 10 columns]

# %% [markdown]
# ## Plot Change in Surface Temperature vs Evapotranspiration
#
# This cell generates a scatter plot showing the relationship between changes in surface temperature and changes in PT-JPL-SM evapotranspiration due to input perturbations. The plot is saved as JPEG and SVG files.

# %%
# plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
# plt.ylim(-350, 150)
plt.scatter(x=results.input_perturbation, y=results.output_perturbation, color='black', s=10, zorder=5)  # Adjust the 's' parameter to make dots thinner
plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in PT-JPL-SM Evapotranspiration (mm/day)")
plt.title("Comparison of Change\nin Surface Temperature\nto PT-JPL-SM Evapotranspiration")

plt.savefig("Comparison of Change in Surface Temperature to PT-JPL-SM Evapotranspiration.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to PT-JPL-SM Evapotranspiration.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Compute Correlation Between Input and Output Perturbations
#
# This cell calculates the Pearson correlation coefficient between the standardized input and output perturbations, quantifying the strength of their linear relationship.

# %%
correlation = mstats.pearsonr(
    np.array(filtered_results.input_perturbation_std).astype(np.float64), 
    np.array(filtered_results.output_perturbation_std).astype(np.float64)
)[0]

correlation
# Out:
# np.float64(0.686797948180559)

# %% [markdown]
# ## Run Full Sensitivity Analysis for Multiple Inputs
#
# This cell performs a comprehensive sensitivity analysis by perturbing several input variables (surface temperature, NDVI, albedo, air temperature, relative humidity) and measuring their effect on latent heat flux. The results are summarized in a DataFrame.

# %%
input_variables = ["ST_C", "NDVI", "albedo", "Ta_C", "RH"]
output_variables = ["ET_daylight_kg"]

perturbation_df, sensitivity_metrics_df = sensitivity_analysis(
    input_df=input_df,
    input_variables=input_variables,
    output_variables=output_variables,
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

sensitivity_metrics_df
# Out:
# [2025-08-20 18:17:26 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:26 INFO] calculating standard deviation of input variable: ST_C
# [2025-08-20 18:17:26 INFO] input variable ST_C standard deviation: 11.932784328125438
# [2025-08-20 18:17:26 INFO] starting forward process
# [2025-08-20 18:17:26 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:26 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:26 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:26 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:26 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:26 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:26 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:26 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:26 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:26 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:26 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:26 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:26 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given field capacity
# [2025-08-20 18:17:26 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given wilting point
# [2025-08-20 18:17:26 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] using given canopy height
# [2025-08-20 18:17:26 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:26 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:26 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-08-20 18:17:26 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:26 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] started daylight ET upscaling
# [2025-08-20 18:17:26 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:26 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:26 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-08-20 18:17:26 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:26 INFO] forward process completed
# [2025-08-20 18:17:26 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:26 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:26 INFO] starting input perturbation generation
# [2025-08-20 18:17:26 INFO] input perturbation generation completed
# [2025-08-20 18:17:26 INFO] generating control group
# [2025-08-20 18:17:26 INFO] normalizing input perturbations
# [2025-08-20 18:17:26 INFO] applying perturbations
# [2025-08-20 18:17:26 INFO] starting forward process for perturbed input
# [2025-08-20 18:17:27 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:27 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LWout_Wm2 min: 189.028 mean: 484.960 max: 1044.413 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Rn_Wm2 min: 0.000 mean: 501.289 max: 1017.018 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 304.888 max: 574.431 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] Verma net radiation processing complete in 0.33 seconds
# [2025-08-20 18:17:27 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:27 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:27 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:27 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:27 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:27 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:27 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:27 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:27 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:27 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:27 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given field capacity
# [2025-08-20 18:17:27 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given wilting point
# [2025-08-20 18:17:27 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] using given canopy height
# [2025-08-20 18:17:27 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:27 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:27 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LWout_Wm2 min: 189.028 mean: 484.960 max: 1044.413 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Rn_Wm2 min: 0.000 mean: 501.289 max: 1017.018 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:27 INFO] variable Rn_Wm2 min: 0.000 mean: 501.289 max: 1017.018 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:27 INFO] variable G min: 0.000 mean: 70.894 max: 200.682 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 324.375 max: 873.379 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LE_soil_Wm2 min: 0.000 mean: 52.861 max: 556.341 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 176.914 max: 842.640 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable PET min: 0.000 mean: 390.121 max: 1029.768 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable fTRM min: 0.047 mean: 0.832 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 121.327 max: 599.690 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LE_interception_Wm2 min: 0.000 mean: 6.611 max: 125.344 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LE_Wm2 min: 0.000 mean: 180.800 max: 799.245 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] started daylight ET upscaling
# [2025-08-20 18:17:27 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 304.888 max: 574.431 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable EF min: 0.000 mean: 0.403 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:27 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 124.966 max: 482.628 nan: 0.00% (nan)
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
# [2025-08-20 18:17:28 INFO] variable ET_daylight_kg min: 0.000 mean: 2.463 max: 10.232 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] completed daylight ET upscaling (elapsed: 0.32 seconds)
# [2025-08-20 18:17:28 INFO] PT-JPL-SM model run complete (elapsed: 0.36 seconds)
# [2025-08-20 18:17:28 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:28 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:28 INFO] normalizing output perturbations
# [2025-08-20 18:17:28 INFO] Monte Carlo run complete
# [2025-08-20 18:17:28 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:28 INFO] calculating standard deviation of input variable: NDVI
# [2025-08-20 18:17:28 INFO] input variable NDVI standard deviation: 0.22705704222349857
# [2025-08-20 18:17:28 INFO] starting forward process
# [2025-08-20 18:17:28 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:28 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:28 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:28 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:28 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:28 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:28 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:28 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:28 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:28 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:28 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:28 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:28 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given field capacity
# [2025-08-20 18:17:28 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given wilting point
# [2025-08-20 18:17:28 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] using given canopy height
# [2025-08-20 18:17:28 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:28 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:28 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-08-20 18:17:28 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:28 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] started daylight ET upscaling
# [2025-08-20 18:17:28 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:28 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-08-20 18:17:28 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:28 INFO] forward process completed
# [2025-08-20 18:17:28 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:28 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:28 INFO] starting input perturbation generation
# [2025-08-20 18:17:28 INFO] input perturbation generation completed
# [2025-08-20 18:17:28 INFO] generating control group
# [2025-08-20 18:17:28 INFO] normalizing input perturbations
# [2025-08-20 18:17:28 INFO] applying perturbations
# [2025-08-20 18:17:28 INFO] starting forward process for perturbed input
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perturbation_df = pd.concat([perturbation_df, run_results])
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sensitivity_metrics_df = pd.concat([sensitivity_metrics_df, pd.DataFrame([[
# [2025-08-20 18:17:28 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:28 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:28 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] Verma net radiation processing complete in 0.32 seconds
# [2025-08-20 18:17:29 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:29 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:29 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:29 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:29 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:29 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given field capacity
# [2025-08-20 18:17:29 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given wilting point
# [2025-08-20 18:17:29 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given canopy height
# [2025-08-20 18:17:29 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:29 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:29 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:29 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:29 INFO] variable G min: 0.000 mean: 68.908 max: 191.504 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_soil_Wm2 min: 0.115 mean: 283.350 max: 777.513 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_soil_Wm2 min: 0.011 mean: 55.194 max: 573.753 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_canopy_Wm2 min: 1.648 mean: 221.683 max: 802.187 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable PET min: 33.264 mean: 394.576 max: 770.662 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable fTRM min: 0.067 mean: 0.822 max: 1.000 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_canopy_Wm2 min: 0.329 mean: 153.497 max: 682.729 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_interception_Wm2 min: 0.016 mean: 7.841 max: 114.665 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_Wm2 min: 2.033 mean: 216.533 max: 737.382 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] started daylight ET upscaling
# [2025-08-20 18:17:29 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable EF min: 0.009 mean: 0.477 max: 0.968 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_daylight_Wm2 min: 1.502 mean: 149.546 max: 385.079 nan: 16.67% (nan)
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/carlson_leaf_area_index/carlson_leaf_area_index.py:66: RuntimeWarning: divide by zero encountered in log
#   LAI = rt.clip(-np.log(1 - fIPAR) * (1 / KPAR), min_LAI, max_LAI)  # Beer-Lambert law for canopy
# [2025-08-20 18:17:29 INFO] variable ET_daylight_kg min: 0.022 mean: 2.947 max: 8.709 nan: 16.67% (nan)
# [2025-08-20 18:17:29 INFO] completed daylight ET upscaling (elapsed: 0.25 seconds)
# [2025-08-20 18:17:29 INFO] PT-JPL-SM model run complete (elapsed: 0.33 seconds)
# [2025-08-20 18:17:29 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:29 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:29 INFO] normalizing output perturbations
# [2025-08-20 18:17:29 INFO] Monte Carlo run complete
# [2025-08-20 18:17:29 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:29 INFO] calculating standard deviation of input variable: albedo
# [2025-08-20 18:17:29 INFO] input variable albedo standard deviation: 0.04798620998842196
# [2025-08-20 18:17:29 INFO] starting forward process
# [2025-08-20 18:17:29 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:29 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:29 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:29 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:29 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:29 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:29 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:29 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:29 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given field capacity
# [2025-08-20 18:17:29 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given wilting point
# [2025-08-20 18:17:29 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] using given canopy height
# [2025-08-20 18:17:29 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:29 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:29 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-08-20 18:17:29 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:29 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] started daylight ET upscaling
# [2025-08-20 18:17:29 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:29 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:29 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-08-20 18:17:29 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:29 INFO] forward process completed
# [2025-08-20 18:17:29 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:29 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:29 INFO] starting input perturbation generation
# [2025-08-20 18:17:29 INFO] input perturbation generation completed
# [2025-08-20 18:17:29 INFO] generating control group
# [2025-08-20 18:17:29 INFO] normalizing input perturbations
# [2025-08-20 18:17:29 INFO] applying perturbations
# [2025-08-20 18:17:29 INFO] starting forward process for perturbed input
# [2025-08-20 18:17:30 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:30 INFO] variable SWout_Wm2 min: 0.000 mean: 82.002 max: 403.830 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable SWnet_Wm2 min: 81.913 mean: 640.534 max: 1087.000 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Rn_Wm2 min: 33.917 mean: 504.891 max: 909.710 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Rn_daylight_Wm2 min: 37.942 mean: 307.165 max: 488.100 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] Verma net radiation processing complete in 0.33 seconds
# [2025-08-20 18:17:30 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:30 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:30 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:30 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:30 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:30 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:30 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:30 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:30 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:30 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:30 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given field capacity
# [2025-08-20 18:17:30 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given wilting point
# [2025-08-20 18:17:30 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] using given canopy height
# [2025-08-20 18:17:30 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:30 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:30 INFO] variable SWout_Wm2 min: 0.000 mean: 82.002 max: 403.830 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable SWnet_Wm2 min: 81.913 mean: 640.534 max: 1087.000 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Rn_Wm2 min: 33.917 mean: 504.891 max: 909.710 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:30 INFO] variable Rn_Wm2 min: 33.917 mean: 504.891 max: 909.710 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:30 INFO] variable G min: 0.628 mean: 74.705 max: 191.510 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Rn_soil_Wm2 min: 3.763 mean: 326.823 max: 763.199 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LE_soil_Wm2 min: 0.577 mean: 52.464 max: 400.437 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable Rn_canopy_Wm2 min: 12.992 mean: 178.069 max: 762.574 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable PET min: 24.934 mean: 389.968 max: 787.653 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LE_canopy_Wm2 min: 4.162 mean: 122.130 max: 536.176 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LE_interception_Wm2 min: 0.098 mean: 6.644 max: 109.229 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LE_Wm2 min: 5.227 mean: 181.238 max: 660.453 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] started daylight ET upscaling
# [2025-08-20 18:17:30 INFO] variable Rn_daylight_Rn_Wm2 min: 37.942 mean: 307.165 max: 488.100 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:30 INFO] variable LE_daylight_Wm2 min: 3.877 mean: 126.019 max: 419.567 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable ET_daylight_kg min: 0.056 mean: 2.483 max: 8.884 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] completed daylight ET upscaling (elapsed: 0.25 seconds)
# [2025-08-20 18:17:31 INFO] PT-JPL-SM model run complete (elapsed: 0.32 seconds)
# [2025-08-20 18:17:31 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:31 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:31 INFO] normalizing output perturbations
# [2025-08-20 18:17:31 INFO] Monte Carlo run complete
# [2025-08-20 18:17:31 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:31 INFO] calculating standard deviation of input variable: Ta_C
# [2025-08-20 18:17:31 INFO] input variable Ta_C standard deviation: 7.468734869126253
# [2025-08-20 18:17:31 INFO] starting forward process
# [2025-08-20 18:17:31 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:31 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:31 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:31 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:31 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:31 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:31 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:31 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:31 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:31 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:31 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:31 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:31 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given field capacity
# [2025-08-20 18:17:31 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given wilting point
# [2025-08-20 18:17:31 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] using given canopy height
# [2025-08-20 18:17:31 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:31 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:31 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-08-20 18:17:31 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:31 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] started daylight ET upscaling
# [2025-08-20 18:17:31 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:31 INFO] PT-JPL-SM model run complete (elapsed: 0.05 seconds)
# [2025-08-20 18:17:31 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:31 INFO] forward process completed
# [2025-08-20 18:17:31 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:31 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:31 INFO] starting input perturbation generation
# [2025-08-20 18:17:31 INFO] input perturbation generation completed
# [2025-08-20 18:17:31 INFO] generating control group
# [2025-08-20 18:17:31 INFO] normalizing input perturbations
# [2025-08-20 18:17:31 INFO] applying perturbations
# [2025-08-20 18:17:31 INFO] starting forward process for perturbed input
# [2025-08-20 18:17:31 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:31 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWin_Wm2 min: 165.641 mean: 349.190 max: 662.198 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_Wm2 min: 0.000 mean: 509.437 max: 1085.323 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 310.019 max: 557.276 nan: 0.00% (nan)
# [2025-08-20 18:17:31 INFO] Verma net radiation processing complete in 0.32 seconds
# [2025-08-20 18:17:31 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:32 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:32 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:32 INFO] variable Ta_C min: -16.725 mean: 23.208 max: 59.619 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:32 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:32 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given field capacity
# [2025-08-20 18:17:32 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given wilting point
# [2025-08-20 18:17:32 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given canopy height
# [2025-08-20 18:17:32 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:32 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:32 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWin_Wm2 min: 165.641 mean: 349.190 max: 662.198 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_Wm2 min: 0.000 mean: 509.437 max: 1085.323 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:32 INFO] variable Rn_Wm2 min: 0.000 mean: 509.437 max: 1085.323 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:32 INFO] variable G min: 0.000 mean: 75.702 max: 242.749 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 0.100 mean: 24.204 max: 59.619 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable epsilon min: 0.174 mean: 0.704 max: 0.932 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 329.685 max: 833.069 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_soil_Wm2 min: 0.000 mean: 52.919 max: 504.095 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 179.752 max: 858.174 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable PET min: 0.000 mean: 393.044 max: 1100.708 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fTRM min: 0.047 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 122.225 max: 729.234 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_interception_Wm2 min: 0.000 mean: 6.721 max: 154.756 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_Wm2 min: 0.000 mean: 181.865 max: 840.950 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] started daylight ET upscaling
# [2025-08-20 18:17:32 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 310.019 max: 557.276 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable EF min: 0.000 mean: 0.396 max: 1.121 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 126.646 max: 593.457 nan: 0.00% (nan)
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
# [2025-08-20 18:17:32 INFO] variable ET_daylight_kg min: 0.000 mean: 2.496 max: 12.632 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] completed daylight ET upscaling (elapsed: 0.25 seconds)
# [2025-08-20 18:17:32 INFO] PT-JPL-SM model run complete (elapsed: 0.34 seconds)
# [2025-08-20 18:17:32 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:32 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:32 INFO] normalizing output perturbations
# [2025-08-20 18:17:32 INFO] Monte Carlo run complete
# [2025-08-20 18:17:32 INFO] tarting Monte Carlo perturbed run
# [2025-08-20 18:17:32 INFO] calculating standard deviation of input variable: RH
# [2025-08-20 18:17:32 INFO] input variable RH standard deviation: 0.08657371001244944
# [2025-08-20 18:17:32 INFO] starting forward process
# [2025-08-20 18:17:32 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:32 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:32 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:32 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:32 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:32 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:32 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:32 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:32 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given field capacity
# [2025-08-20 18:17:32 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given wilting point
# [2025-08-20 18:17:32 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] using given canopy height
# [2025-08-20 18:17:32 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:32 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:32 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-08-20 18:17:32 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:32 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] started daylight ET upscaling
# [2025-08-20 18:17:32 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-08-20 18:17:32 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-08-20 18:17:32 INFO] PT-JPL-SM model run complete (elapsed: 0.05 seconds)
# [2025-08-20 18:17:32 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:32 INFO] forward process completed
# [2025-08-20 18:17:32 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-08-20 18:17:32 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-08-20 18:17:32 INFO] starting input perturbation generation
# [2025-08-20 18:17:32 INFO] input perturbation generation completed
# [2025-08-20 18:17:32 INFO] generating control group
# [2025-08-20 18:17:32 INFO] normalizing input perturbations
# [2025-08-20 18:17:32 INFO] applying perturbations
# [2025-08-20 18:17:32 INFO] starting forward process for perturbed input
# [2025-08-20 18:17:33 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:33 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LWin_Wm2 min: 222.741 mean: 344.651 max: 484.937 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Rn_Wm2 min: 33.259 mean: 504.889 max: 821.302 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Rn_daylight_Wm2 min: 37.207 mean: 307.129 max: 440.665 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] Verma net radiation processing complete in 0.32 seconds
# [2025-08-20 18:17:33 INFO] starting PT-JPL-SM table processing
# [2025-08-20 18:17:33 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:33 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-08-20 18:17:33 INFO] started extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:33 INFO] completed extracting time from PT-JPL-SM input table
# [2025-08-20 18:17:33 INFO] starting PT-JPL-SM model run
# [2025-08-20 18:17:33 INFO] using given optimum temperature (Topt_C)
# [2025-08-20 18:17:33 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given air temperature (Ta_C)
# [2025-08-20 18:17:33 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given relative humidity (RH)
# [2025-08-20 18:17:33 INFO] variable RH min: -0.024 mean: 0.385 max: 1.121 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given soil moisture (SM)
# [2025-08-20 18:17:33 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given field capacity
# [2025-08-20 18:17:33 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given wilting point
# [2025-08-20 18:17:33 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] using given canopy height
# [2025-08-20 18:17:33 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] running Verma net radiation with daylight upscaling
# [2025-08-20 18:17:33 INFO] starting Verma net radiation processing
# [2025-08-20 18:17:33 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LWin_Wm2 min: 222.741 mean: 344.651 max: 484.937 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Rn_Wm2 min: 33.259 mean: 504.889 max: 821.302 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-08-20 18:17:33 INFO] variable Rn_Wm2 min: 33.259 mean: 504.889 max: 821.302 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] calculating soil heat flux (G_Wm2)
# [2025-08-20 18:17:33 INFO] variable G min: 0.574 mean: 75.050 max: 198.325 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable fwet min: 0.000 mean: 0.038 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Rn_soil_Wm2 min: 3.690 mean: 326.710 max: 685.668 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LE_soil_Wm2 min: 0.000 mean: 53.563 max: 345.242 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable Rn_canopy_Wm2 min: 17.285 mean: 178.179 max: 705.870 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable PET min: 24.549 mean: 389.625 max: 725.329 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable fTRM min: 0.005 mean: 0.820 max: 1.000 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 119.868 max: 515.266 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LE_interception_Wm2 min: 0.000 mean: 8.092 max: 316.159 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LE_Wm2 min: 5.842 mean: 181.523 max: 631.882 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] started daylight ET upscaling
# [2025-08-20 18:17:33 INFO] variable Rn_daylight_Rn_Wm2 min: 37.207 mean: 307.129 max: 440.665 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable EF min: 0.032 mean: 0.405 max: 0.967 nan: 0.00% (nan)
# [2025-08-20 18:17:33 INFO] variable LE_daylight_Wm2 min: 4.315 mean: 126.313 max: 390.935 nan: 0.00% (nan)
# [2025-08-20 18:17:34 INFO] variable ET_daylight_kg min: 0.063 mean: 2.489 max: 8.480 nan: 0.00% (nan)
# [2025-08-20 18:17:34 INFO] completed daylight ET upscaling (elapsed: 0.27 seconds)
# [2025-08-20 18:17:34 INFO] PT-JPL-SM model run complete (elapsed: 0.33 seconds)
# [2025-08-20 18:17:34 INFO] PT-JPL-SM table processing complete
# [2025-08-20 18:17:34 INFO] completed forward process for perturbed input
# [2025-08-20 18:17:34 INFO] normalizing output perturbations
# [2025-08-20 18:17:34 INFO] Monte Carlo run complete
#   input_variable output_variable                  metric     value
# 0           ST_C  ET_daylight_kg             correlation  0.675675
# 0           ST_C  ET_daylight_kg                      r2  0.456537
# 0           ST_C  ET_daylight_kg  mean_normalized_change  0.108132
# 0           NDVI  ET_daylight_kg             correlation  0.845734
# 0           NDVI  ET_daylight_kg                      r2  0.715267
# 0           NDVI  ET_daylight_kg  mean_normalized_change  0.525417
# 0         albedo  ET_daylight_kg             correlation  0.754164
# 0         albedo  ET_daylight_kg                      r2  0.568764
# 0         albedo  ET_daylight_kg  mean_normalized_change  0.048122
# 0           Ta_C  ET_daylight_kg             correlation  0.807186
# 0           Ta_C  ET_daylight_kg                      r2  0.651548
# 0           Ta_C  ET_daylight_kg  mean_normalized_change  0.201559
# 0             RH  ET_daylight_kg             correlation  0.423274
# 0             RH  ET_daylight_kg                      r2  0.179161
# 0             RH  ET_daylight_kg  mean_normalized_change  0.027289

# %% [markdown]
# ## Plot Sensitivity Magnitude Bar Chart
#
# This cell creates a bar chart showing the average percent change in latent heat flux for each input variable, visualizing the magnitude of model sensitivity to each input. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "ET_daylight_kg") & (df.metric == "mean_normalized_change")]
ax = sns.barplot(x=df.input_variable, y=df.value * 100, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
plt.xlabel("Input Variable")
plt.ylabel("Average Percent Change in Output Perturbation")
plt.title("PT-JPL-SM Evapotranspiration Sensitivity Magnitude")
# plt.ylim(0, 160)  # Set y-axis range from 0 to 160
plt.grid(axis='y', color='lightgray', linestyle='-', linewidth=0.5)  # Add light gray horizontal gridlines only

# Add percent sign to y-axis tick labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{int(y)}%'))

plt.savefig("PT-JPL-SM Evapotranspiration Sensitivity Magnitude.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL-SM Evapotranspiration Sensitivity Magnitude.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_14374/323368046.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Plot Sensitivity Correlation Bar Chart
#
# This cell generates a bar chart showing the correlation between input perturbations and output perturbations for each input variable, highlighting which inputs most strongly influence latent heat flux. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "ET_daylight_kg") & (df.metric == "correlation")]
ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
# plt.ylim(0, 0.8)
plt.xlabel("Input Variable")
plt.ylabel("Correlation of Input Perturbation to Output Perturbation")
plt.title("PT-JPL-SM Latent Heat Flux Sensitivity Correlation")
plt.grid(axis='y')  # Add horizontal gridlines

plt.savefig("PT-JPL-SM Latent Heat Flux Sensitivity Correlation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL-SM Latent Heat Flux Sensitivity Correlation.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_14374/2799509377.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Summary and Next Steps
#
# This notebook demonstrated a full sensitivity analysis workflow for the PT-JPL-SM model using ECOSTRESS Cal-Val data. Key results include the identification of input variables with the greatest influence on latent heat flux. Next steps could include further exploration of model parameters, additional visualizations, or application to other datasets.
