# %% [markdown]
# # PT-JPL-SM Sensitivity Analysis with ECOv002 Cal-Val
#
# This notebook performs a sensitivity analysis of the PT-JPL-SM model using ECOSTRESS Collection 2 Cal-Val data. It loads input data, processes it through the PT-JPL-SM model, and visualizes the impact of input perturbations on latent heat flux. The notebook also generates figures for publication and explores the relationship between surface temperature and latent heat flux.

# %% [markdown]
# ## Import Required Libraries and Functions
#
# This cell imports all necessary libraries and functions for data processing, model execution, statistical analysis, and plotting. It includes custom modules for the PT-JPL-SM model, sensitivity analysis, and net radiation calculations, as well as standard scientific Python libraries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

# %%
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table
from PTJPLSM import process_PTJPLSM_table, load_ECOv002_calval_PTJPLSM_inputs
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Set Normalization Function
#
# This cell assigns the normalization function used to compare perturbed model outputs to the unperturbed baseline. The function `divide_absolute_by_unperturbed` is used for normalization in the sensitivity analysis.

# %%
normalization_function = divide_absolute_by_unperturbed

# %% [markdown]
# ## Load and Filter Input Data
#
# This cell loads the ECOSTRESS Cal-Val input data using a custom loader function and filters out rows where `fAPARmax` is zero. The resulting DataFrame is displayed for inspection.

# %%
input_df = load_ECOv002_calval_PTJPLSM_inputs()
input_df = input_df[input_df.fAPARmax != 0]
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C  \
# 0     392.851840   307.021970  487.383423         118.916280  ...  31.95
# 1     640.118470   375.089300  106.825577         167.919460  ...  31.19
# 2     625.661700   284.686250         NaN         132.936340  ...  30.91
# 3     624.254330   251.414490  178.827545         141.132420  ...  28.65
# 4     511.082180   228.520170  154.791626         114.809410  ...  30.03
# ...          ...          ...         ...                ...  ...    ...
# 1060   81.645230    15.282976         NaN          56.385185  ...   5.63
# 1061   65.469320    22.186659         NaN          40.509410  ...  20.13
# 1062  118.777240    55.343586         NaN          52.403820  ...  28.79
# 1063  126.490524    40.434025         NaN          57.769722  ...  17.57
# 1064  271.749480   119.763630  190.823303         122.092445  ...  41.61
#
#            Ta_C   SWin_Wm2  emissivity  \
# 0     32.658920  545.51056       0.948
# 1     24.227982  848.34390       0.952
# 2     26.178862  838.81160       0.972
# 3     22.527096  851.72480       0.974
# 4     23.280691  702.55160       0.960
# ...         ...        ...         ...
# 1060   3.815752  286.84660       0.980
# 1061  19.266186  290.87400       0.976
# 1062  32.110336  352.19530       0.976
# 1063  10.464681  420.67880       0.976
# 1064  30.316103  781.84110       0.978
#
#                                               name  Topt_C  fAPARmax  \
# 0                                    NC_Clearcut#3   10.09    0.4659
# 1     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 2     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 3     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# 4     LTAR UCB (Upper Chesapeake Bay) Miscanthus 3    1.39    0.4865
# ...                                            ...     ...       ...
# 1060     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1061     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1062     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1063     NEON Klemme Range Research Station (OAES)    7.99    0.3387
# 1064     NEON Klemme Range Research Station (OAES)    7.99    0.3387
#
#       canopy_height_meters  field_capacity  wilting_point
# 0                20.642902            0.24           0.11
# 1                 0.000000            0.31           0.14
# 2                 0.000000            0.31           0.14
# 3                 0.000000            0.31           0.14
# 4                 0.000000            0.31           0.14
# ...                    ...             ...            ...
# 1060              0.000000            0.28           0.13
# 1061              0.000000            0.28           0.13
# 1062              0.000000            0.28           0.13
# 1063              0.000000            0.28           0.13
# 1064              0.000000            0.28           0.13
#
# [1065 rows x 83 columns]

# %% [markdown]
# ## Check Minimum fAPARmax Value
#
# This cell computes the minimum value of `fAPARmax` in the filtered input data to verify the filtering step and ensure no zero values remain.

# %%
np.nanmin(input_df.fAPARmax)
# Out:
# np.float64(0.2331)

# %% [markdown]
# ## Define Processing Function for Model Table
#
# This cell defines a helper function that processes the input DataFrame through the Verma net radiation calculation and then the PT-JPL-SM model. This function is used in later analysis steps.

# %%
def process_verma_PTJPLSM_table(input_df: pd.DataFrame) -> pd.DataFrame:
    return process_PTJPLSM_table(verma_net_radiation_table(input_df), upscale_to_daylight=True)

# %% [markdown]
# ## Process Input Data Through Model
#
# This cell applies the processing function to the filtered input data, running it through the Verma net radiation and PT-JPL-SM model, and displays the resulting DataFrame.

# %%
processed = process_verma_PTJPLSM_table(input_df)
processed
# Out:
# [2025-09-08 11:53:38 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:38 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.722 max: 443.569 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-08 11:53:38 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:38 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:38 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:38 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:38 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:38 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:38 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:38 INFO] variable Topt_C min: 0.000 mean: 8.174 max: 23.210 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable fAPARmax min: 0.233 mean: 0.382 max: 0.624 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:38 INFO] variable Ta_C min: -14.605 mean: 22.322 max: 39.710 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:38 INFO] variable RH min: 0.273 mean: 0.427 max: 0.984 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:38 INFO] variable soil_moisture min: 0.000 mean: 0.168 max: 0.897 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given field capacity
# [2025-09-08 11:53:38 INFO] variable field_capacity min: 0.190 mean: 0.283 max: 0.390 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given wilting point
# [2025-09-08 11:53:38 INFO] variable wilting_point min: 0.040 mean: 0.121 max: 0.290 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] using given canopy height
# [2025-09-08 11:53:38 INFO] variable canopy_height_meters min: 0.000 mean: 6.044 max: 30.192 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:38 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:38 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-09-08 11:53:38 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# 2           4.228934
# 3           4.065880
# 4           3.624539
# ...              ...
# 1060        0.176834
# 1061        0.484122
# 1062        1.367768
# 1063        0.735651
# 1064        1.526165
#
# [1065 rows x 100 columns]

# %% [markdown]
# ## Plot Unperturbed Comparison of Surface Temperature to Latent Heat Flux
#
# This cell creates a scatter plot comparing ECOSTRESS surface temperature to PT-JPL-SM latent heat flux for the unperturbed data. The plot is saved as both JPEG and SVG files for publication or further analysis.

# %%
plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
plt.scatter(x=processed.ST_C, y=processed.ET_daylight_kg, color='black', s=10, zorder=5)
plt.grid(True, zorder=0)
plt.xlabel("ECOSTRESS Surface Temperature (°C)")
plt.ylabel("PT-JPL-SM Daily ET (mm/day)")
plt.title("Unperturbed Comparison\nof ECOSTRESS Surface Temperature\nto PT-JPL-SM Evapotranspiration")

plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL-SM Evapotranspiration.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL-SM Evapotranspiration.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Further Filter Input Data and Check Temperature Range
#
# This cell applies additional filters to the input data, ensuring only valid `fAPARmax` and `NDVI` values are included. It also checks the minimum and maximum surface temperature values in the filtered dataset.

# %%
# input_df = pd.read_csv(input_filename)
input_df = load_ECOv002_calval_PTJPLSM_inputs()

if "Ta" in input_df and "Ta_C" not in input_df:
    # input_df.rename({"Ta": "Ta_C"}, inplace=True)
    input_df["Ta_C"] = input_df["Ta"]

input_df = input_df[input_df.fAPARmax.apply(lambda fAPARmax: fAPARmax > 0.001)]
input_df = input_df[input_df.NDVI.apply(lambda NDVI: NDVI > 0.05)]

np.nanmin(input_df.ST_C), np.nanmax(input_df.ST_C)
# Out:
# (np.float64(-13.189999999999998), np.float64(86.11000000000001))

# %% [markdown]
# ## Check Number of Valid Input Rows
#
# This cell displays the number of rows remaining in the input DataFrame after all filtering steps, confirming the size of the dataset used for analysis.

# %%
len(input_df)
# Out:
# 1063

# %%
input_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'vegetation', 'climate', 'STICinst', 'BESSinst',
#        'MOD16inst', 'PTJPLSMinst', 'ETinst', 'ETinstUncertainty', 'PET', 'Rn',
#        'ESI', 'RH', 'Ta', 'LST', 'SM', 'NDVI', 'NDVI-UQ', 'albedo',
#        'albedo-UQ', 'LST_err', 'view_zenith', 'Rg', 'EmisWB', 'time_utc',
#        'solar_time', 'solar_hour', 'local_time', 'LE', 'LE_filt', 'LEcorr25',
#        'LEcorr50', 'LEcorr75', 'LEcorr_ann', 'H_filt', 'Hcorr25', 'Hcorr50',
#        'Hcorr75', 'Hcorr_ann', 'NETRAD_filt', 'G_filt', 'SM_surf', 'SM_rz',
#        'AirTempC', 'SW_IN', 'RH_percentage', 'ESIrn_STIC', 'ESIrn_PTJPLSM',
#        'ESIrn_MOD16', 'ESIrn_BESS', 'ESIrn_Unc_ECO', 'ESIrn_LEcorr50', 'JET',
#        'eco_time_utc', 'Site Name', 'Date-Time', 'Site ID', 'Name', 'Lat',
#        'Long', 'Elev', 'Clim', 'Veg', 'MAT', 'MAP', 'StartDate', 'EndDate',
#        'LE_count', 'closure_ratio', 'geometry', 'time_UTC', 'ST_K', 'ST_C',
#        'Ta_C', 'SWin_Wm2', 'emissivity', 'name', 'Topt_C', 'fAPARmax',
#        'canopy_height_meters', 'field_capacity', 'wilting_point'],
#       dtype='object')

# %%
input_df["SWin_Wm2"] = input_df["SW_IN"]
input_df["emissivity"] = input_df["EmisWB"]

# %%
# Ensure all relevant columns are numeric before sensitivity analysis
for col in ["albedo", "SWin_Wm2", "ST_C", "emissivity", "Ta_C", "RH"]:
    if col in input_df.columns:
        input_df[col] = pd.to_numeric(input_df[col], errors="coerce")
# Drop rows with NaN in any relevant column
input_df = input_df.dropna(subset=["albedo", "SWin_Wm2", "ST_C", "emissivity", "Ta_C", "RH"])

# %%
input_df = input_df.dropna()
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  MOD16inst  \
# 15            15  US-xAB        ENF     Csb  141.635670  168.24043  402.81810
# 17            17  US-xAB        ENF     Csb    1.881266  163.94730  301.40400
# 18            18  US-xAB        ENF     Csb    3.135606  246.87700  614.51480
# 19            19  US-xAB        ENF     Csb  311.482820  290.73126  672.27510
# 20            20  US-xAB        ENF     Csb   51.920338   95.28810  116.67136
# ...          ...     ...        ...     ...         ...        ...        ...
# 992          992  US-xML        DBF     Dfb  417.831120  706.93066  523.92740
# 994          994  US-xML        DBF     Dfb  161.558200  306.15277  420.44678
# 1001        1001  US-UiB        CRO     Dfa   93.876100  251.38747  238.71077
# 1020        1020  US-ARM        CRO     Cfa   80.255005    0.00000  180.10085
# 1021        1021  US-ARM        CRO     Cfa  126.236190    0.00000  199.79102
#
#       PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C       Ta_C  \
# 15      159.71700  139.016083         107.183200  ...  20.01  15.849697
# 17      179.13661  131.273636         106.525215  ...  14.63  14.842857
# 18      405.50497  366.056641         222.890230  ...  24.97  21.549250
# 19      478.82382  439.821228         153.787670  ...  33.03  26.457556
# 20       73.20884  232.693512          24.038680  ...  10.93  12.976667
# ...           ...         ...                ...  ...    ...        ...
# 992     310.69684  356.174072         148.624050  ...  16.47  16.969240
# 994     206.48576  237.659103          98.727560  ...  13.17  14.792879
# 1001    198.90399  106.316444          67.694800  ...  25.93   9.609989
# 1020    211.28325  164.581390          84.672410  ...  31.85  22.611721
# 1021    232.13673  281.860535          89.163790  ...  35.23  23.101131
#
#       SWin_Wm2  emissivity                                          name  \
# 15     574.985       0.972                         NEON Abby Road (ABBY)
# 17     386.290       0.978                         NEON Abby Road (ABBY)
# 18     876.800       0.976                         NEON Abby Road (ABBY)
# 19     948.235       0.974                         NEON Abby Road (ABBY)
# 20      98.315       0.954                         NEON Abby Road (ABBY)
# ...        ...         ...                                           ...
# 992    735.490       0.972  NEON Mountain Lake Biological Station (MLBS)
# 994    554.470       0.972  NEON Mountain Lake Biological Station (MLBS)
# 1001  1008.000       0.946             University of Illinois Miscanthus
# 1020   701.520       0.958        ARM Southern Great Plains site- Lamont
# 1021   749.332       0.952        ARM Southern Great Plains site- Lamont
#
#       Topt_C  fAPARmax  canopy_height_meters  field_capacity  wilting_point
# 15      6.69    0.6040              6.244725            0.33           0.16
# 17      6.69    0.6040              6.244725            0.33           0.16
# 18      6.69    0.6040              6.244725            0.33           0.16
# 19      6.69    0.6040              6.244725            0.33           0.16
# 20      6.69    0.6040              6.244725            0.33           0.16
# ...      ...       ...                   ...             ...            ...
# 992     2.66    0.5404             23.197309            0.34           0.14
# 994     2.66    0.5404             23.197309            0.34           0.14
# 1001    2.58    0.4060              0.000000            0.32           0.14
# 1020    8.48    0.4017              0.000000            0.29           0.12
# 1021    8.48    0.4017              0.000000            0.29           0.12
#
# [295 rows x 83 columns]

# %% [markdown]
# ## Run Perturbed Model Analysis
#
# This cell sets up the input and output variables for the sensitivity analysis and runs the `perturbed_run` function, which perturbs the input variable and observes the effect on the output variable using the PT-JPL-SM model. The results are displayed for further analysis.

# %%
input_variable = "ST_C"
output_variable = "ET_daylight_kg"

results = perturbed_run(
    input_df=input_df, 
    input_variable=input_variable, 
    output_variable=output_variable, 
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

results
# Out:
# [2025-09-08 11:53:39 INFO] tarting Monte Carlo perturbed run
# [2025-09-08 11:53:39 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-08 11:53:39 INFO] input variable ST_C standard deviation: 11.932784328125438
# [2025-09-08 11:53:39 INFO] starting forward process
# [2025-09-08 11:53:39 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:39 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:39 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:39 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:39 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:39 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:39 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:39 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:39 INFO] variable LWout_Wm2 min: 180.720 mean: 485.577 max: 1010.355 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable Rn_Wm2 min: 0.000 mean: 500.683 max: 969.553 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 304.360 max: 594.039 nan: 0.00% (nan)
# [2025-09-08 11:53:39 INFO] Verma net radiation processing complete in 0.30 seconds
# [2025-09-08 11:53:39 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:39 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:40 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:40 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:40 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:40 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given field capacity
# [2025-09-08 11:53:40 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given wilting point
# [2025-09-08 11:53:40 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given canopy height
# [2025-09-08 11:53:40 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:40 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:40 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWout_Wm2 min: 180.720 mean: 485.577 max: 1010.355 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_Wm2 min: 0.000 mean: 500.683 max: 969.553 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:40 INFO] variable Rn_Wm2 min: 0.000 mean: 500.683 max: 969.553 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:40 INFO] variable G min: 0.000 mean: 71.021 max: 200.649 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 323.981 max: 832.659 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_soil_Wm2 min: 0.000 mean: 52.764 max: 507.825 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 176.702 max: 867.366 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable PET min: 0.000 mean: 389.565 max: 983.410 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fTRM min: 0.047 mean: 0.832 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 121.203 max: 636.905 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_interception_Wm2 min: 0.000 mean: 6.585 max: 124.027 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_Wm2 min: 0.000 mean: 180.551 max: 819.403 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] started daylight ET upscaling
# [2025-09-08 11:53:40 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 304.360 max: 594.039 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable EF min: 0.000 mean: 0.403 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 124.811 max: 534.155 nan: 0.00% (nan)
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
# [2025-09-08 11:53:40 INFO] variable ET_daylight_kg min: 0.000 mean: 2.459 max: 10.828 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] completed daylight ET upscaling (elapsed: 0.28 seconds)
# [2025-09-08 11:53:40 INFO] PT-JPL-SM model run complete (elapsed: 0.32 seconds)
# [2025-09-08 11:53:40 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:40 INFO] completed forward process for perturbed input
# [2025-09-08 11:53:40 INFO] normalizing output perturbations
# [2025-09-08 11:53:40 INFO] Monte Carlo run complete
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 0               ST_C  ET_daylight_kg             20.01           -8.298649
# 1               ST_C  ET_daylight_kg             20.01           33.917133
# 2               ST_C  ET_daylight_kg             20.01            2.486030
# 3               ST_C  ET_daylight_kg             20.01           -5.477720
# 4               ST_C  ET_daylight_kg             20.01           -5.640937
# ...              ...             ...               ...                 ...
# 29495           ST_C  ET_daylight_kg             35.23          -18.467364
# 29496           ST_C  ET_daylight_kg             35.23          -28.753523
# 29497           ST_C  ET_daylight_kg             35.23           29.072772
# 29498           ST_C  ET_daylight_kg             35.23           -4.238995
# 29499           ST_C  ET_daylight_kg             35.23          -34.752278
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 0                    0.414725       11.711351           2.734929
# 1                    1.695009       53.927133           2.734929
# 2                    0.124239        22.49603           2.734929
# 3                    0.273749        14.53228           2.734929
# 4                    0.281906       14.369063           2.734929
# ...                       ...             ...                ...
# 29495                0.524194       16.762636           3.783944
# 29496                0.816166        6.476477           3.783944
# 29497                0.825228       64.302772           3.783944
# 29498                0.120323       30.991005           3.783944
# 29499                0.986440        0.477722           3.783944
#
#       output_perturbation output_perturbation_std  output_perturbed
# 0                0.326147                0.119253          3.061076
# 1               -1.510626                0.552346          1.224303
# 2               -0.101135                0.036979          2.633793
# 3                0.217265                0.079441          2.952194
# 4                0.223621                0.081765          2.958549
# ...                   ...                     ...               ...
# 29495            0.839545                 0.22187          4.623488
# 29496            1.249406                0.330186          5.033350
# 29497           -1.610783                0.425689          2.173161
# 29498            0.204904                0.054151          3.988847
# 29499            1.470388                0.388586          5.254331
#
# [29500 rows x 10 columns]

# %% [markdown]
# ## Filter Out NaN Results
#
# This cell removes any rows with missing values from the perturbed results to ensure only valid data points are used in subsequent analysis and plotting.

# %%
filtered_results = results.dropna()
filtered_results
# Out:
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 0               ST_C  ET_daylight_kg             20.01           -8.298649
# 1               ST_C  ET_daylight_kg             20.01           33.917133
# 2               ST_C  ET_daylight_kg             20.01            2.486030
# 3               ST_C  ET_daylight_kg             20.01           -5.477720
# 4               ST_C  ET_daylight_kg             20.01           -5.640937
# ...              ...             ...               ...                 ...
# 29495           ST_C  ET_daylight_kg             35.23          -18.467364
# 29496           ST_C  ET_daylight_kg             35.23          -28.753523
# 29497           ST_C  ET_daylight_kg             35.23           29.072772
# 29498           ST_C  ET_daylight_kg             35.23           -4.238995
# 29499           ST_C  ET_daylight_kg             35.23          -34.752278
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 0                    0.414725       11.711351           2.734929
# 1                    1.695009       53.927133           2.734929
# 2                    0.124239        22.49603           2.734929
# 3                    0.273749        14.53228           2.734929
# 4                    0.281906       14.369063           2.734929
# ...                       ...             ...                ...
# 29495                0.524194       16.762636           3.783944
# 29496                0.816166        6.476477           3.783944
# 29497                0.825228       64.302772           3.783944
# 29498                0.120323       30.991005           3.783944
# 29499                0.986440        0.477722           3.783944
#
#       output_perturbation output_perturbation_std  output_perturbed
# 0                0.326147                0.119253          3.061076
# 1               -1.510626                0.552346          1.224303
# 2               -0.101135                0.036979          2.633793
# 3                0.217265                0.079441          2.952194
# 4                0.223621                0.081765          2.958549
# ...                   ...                     ...               ...
# 29495            0.839545                 0.22187          4.623488
# 29496            1.249406                0.330186          5.033350
# 29497           -1.610783                0.425689          2.173161
# 29498            0.204904                0.054151          3.988847
# 29499            1.470388                0.388586          5.254331
#
# [29500 rows x 10 columns]

# %% [markdown]
# ## Plot Change in Surface Temperature vs Evapotranspiration
#
# This cell generates a scatter plot showing the relationship between changes in surface temperature and changes in PT-JPL-SM evapotranspiration due to input perturbations. The plot is saved as JPEG and SVG files.

# %%
# plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
# plt.ylim(-350, 150)
plt.scatter(x=results.input_perturbation, y=results.output_perturbation, color='black', s=10, zorder=5)  # Adjust the 's' parameter to make dots thinner
plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in PT-JPL-SM Evapotranspiration (mm/day)")
plt.title("Comparison of Change\nin Surface Temperature\nto PT-JPL-SM Evapotranspiration")

plt.savefig("Comparison of Change in Surface Temperature to PT-JPL-SM Evapotranspiration.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to PT-JPL-SM Evapotranspiration.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Compute Correlation Between Input and Output Perturbations
#
# This cell calculates the Pearson correlation coefficient between the standardized input and output perturbations, quantifying the strength of their linear relationship.

# %%
correlation = mstats.pearsonr(
    np.array(filtered_results.input_perturbation_std).astype(np.float64), 
    np.array(filtered_results.output_perturbation_std).astype(np.float64)
)[0]

correlation
# Out:
# np.float64(0.6773428492155489)

# %% [markdown]
# ## Run Full Sensitivity Analysis for Multiple Inputs
#
# This cell performs a comprehensive sensitivity analysis by perturbing several input variables (surface temperature, NDVI, albedo, air temperature, relative humidity) and measuring their effect on latent heat flux. The results are summarized in a DataFrame.

# %%
input_variables = ["ST_C", "NDVI", "albedo", "Ta_C", "RH"]
output_variables = ["ET_daylight_kg"]

perturbation_df, sensitivity_metrics_df = sensitivity_analysis(
    input_df=input_df,
    input_variables=input_variables,
    output_variables=output_variables,
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

sensitivity_metrics_df
# Out:
# [2025-09-08 11:53:40 INFO] tarting Monte Carlo perturbed run
# [2025-09-08 11:53:40 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-08 11:53:40 INFO] input variable ST_C standard deviation: 11.932784328125438
# [2025-09-08 11:53:40 INFO] starting forward process
# [2025-09-08 11:53:40 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:40 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:40 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:40 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:40 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:40 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:40 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:40 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:40 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given field capacity
# [2025-09-08 11:53:40 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given wilting point
# [2025-09-08 11:53:40 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] using given canopy height
# [2025-09-08 11:53:40 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:40 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:40 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-09-08 11:53:40 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:40 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] started daylight ET upscaling
# [2025-09-08 11:53:40 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-09-08 11:53:40 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-09-08 11:53:40 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-09-08 11:53:40 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:40 INFO] forward process completed
# [2025-09-08 11:53:40 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-09-08 11:53:40 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-09-08 11:53:41 INFO] starting input perturbation generation
# [2025-09-08 11:53:41 INFO] input perturbation generation completed
# [2025-09-08 11:53:41 INFO] generating control group
# [2025-09-08 11:53:41 INFO] normalizing input perturbations
# [2025-09-08 11:53:41 INFO] applying perturbations
# [2025-09-08 11:53:41 INFO] starting forward process for perturbed input
# [2025-09-08 11:53:41 INFO] starting Verma net radiation processing
nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] completed daylight ET upscaling (elapsed: 0.30 seconds)
# [2025-09-08 11:53:42 INFO] PT-JPL-SM model run complete (elapsed: 0.35 seconds)
# [2025-09-08 11:53:42 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:42 INFO] completed forward process for perturbed input
# [2025-09-08 11:53:42 INFO] normalizing output perturbations
# [2025-09-08 11:53:42 INFO] Monte Carlo run complete
# [2025-09-08 11:53:42 INFO] tarting Monte Carlo perturbed run
# [2025-09-08 11:53:42 INFO] calculating standard deviation of input variable: NDVI
# [2025-09-08 11:53:42 INFO] input variable NDVI standard deviation: 0.22705704222349857
# [2025-09-08 11:53:42 INFO] starting forward process
# [2025-09-08 11:53:42 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:42 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:42 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:42 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:42 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:42 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:42 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:42 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:42 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:42 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:42 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:42 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:42 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given field capacity
# [2025-09-08 11:53:42 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given wilting point
# [2025-09-08 11:53:42 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] using given canopy height
# [2025-09-08 11:53:42 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:42 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:42 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-09-08 11:53:42 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:42 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] started daylight ET upscaling
# [2025-09-08 11:53:42 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-09-08 11:53:42 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-09-08 11:53:42 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:42 INFO] forward process completed
# [2025-09-08 11:53:42 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-09-08 11:53:42 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-09-08 11:53:42 INFO] starting input perturbation generation
# [2025-09-08 11:53:42 INFO] input perturbation generation completed
# [2025-09-08 11:53:42 INFO] generating control group
# [2025-09-08 11:53:42 INFO] normalizing input perturbations
# [2025-09-08 11:53:42 INFO] applying perturbations
# [2025-09-08 11:53:42 INFO] starting forward process for perturbed input
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perturbation_df = pd.concat([perturbation_df, run_results])
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sensitivity_metrics_df = pd.concat([sensitivity_metrics_df, pd.DataFrame([[
# [2025-09-08 11:53:42 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:42 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:42 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] Verma net radiation processing complete in 0.31 seconds
# [2025-09-08 11:53:43 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:43 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:43 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:43 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:43 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:43 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given field capacity
# [2025-09-08 11:53:43 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given wilting point
# [2025-09-08 11:53:43 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given canopy height
# [2025-09-08 11:53:43 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:43 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:43 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:43 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:43 INFO] variable G min: 0.000 mean: 68.941 max: 191.504 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_soil_Wm2 min: 0.115 mean: 281.367 max: 761.208 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_soil_Wm2 min: 0.017 mean: 54.677 max: 610.363 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_canopy_Wm2 min: 2.062 mean: 224.176 max: 802.187 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable PET min: 33.241 mean: 395.336 max: 770.662 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable fTRM min: 0.065 mean: 0.824 max: 1.000 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_canopy_Wm2 min: 0.411 mean: 155.404 max: 671.218 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_interception_Wm2 min: 0.018 mean: 7.914 max: 114.665 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_Wm2 min: 1.804 mean: 217.995 max: 737.382 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] started daylight ET upscaling
# [2025-09-08 11:53:43 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable EF min: 0.010 mean: 0.480 max: 0.968 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_daylight_Wm2 min: 1.333 mean: 150.424 max: 385.097 nan: 17.24% (nan)
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.12/site-packages/carlson_leaf_area_index/carlson_leaf_area_index.py:66: RuntimeWarning: divide by zero encountered in log
#   LAI = rt.clip(-np.log(1 - fIPAR) * (1 / KPAR), min_LAI, max_LAI)  # Beer-Lambert law for canopy
# [2025-09-08 11:53:43 INFO] variable ET_daylight_kg min: 0.019 mean: 2.967 max: 8.709 nan: 17.24% (nan)
# [2025-09-08 11:53:43 INFO] completed daylight ET upscaling (elapsed: 0.28 seconds)
# [2025-09-08 11:53:43 INFO] PT-JPL-SM model run complete (elapsed: 0.33 seconds)
# [2025-09-08 11:53:43 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:43 INFO] completed forward process for perturbed input
# [2025-09-08 11:53:43 INFO] normalizing output perturbations
# [2025-09-08 11:53:43 INFO] Monte Carlo run complete
# [2025-09-08 11:53:43 INFO] tarting Monte Carlo perturbed run
# [2025-09-08 11:53:43 INFO] calculating standard deviation of input variable: albedo
# [2025-09-08 11:53:43 INFO] input variable albedo standard deviation: 0.04798620998842196
# [2025-09-08 11:53:43 INFO] starting forward process
# [2025-09-08 11:53:43 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:43 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:43 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:43 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:43 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:43 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:43 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:43 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:43 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given field capacity
# [2025-09-08 11:53:43 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given wilting point
# [2025-09-08 11:53:43 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] using given canopy height
# [2025-09-08 11:53:43 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:43 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:43 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-09-08 11:53:43 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:43 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] started daylight ET upscaling
# [2025-09-08 11:53:43 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-09-08 11:53:43 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-09-08 11:53:43 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-09-08 11:53:43 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:43 INFO] forward process completed
# [2025-09-08 11:53:43 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-09-08 11:53:43 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-09-08 11:53:43 INFO] starting input perturbation generation
# [2025-09-08 11:53:43 INFO] input perturbation generation completed
# [2025-09-08 11:53:43 INFO] generating control group
# [2025-09-08 11:53:43 INFO] normalizing input perturbations
# [2025-09-08 11:53:43 INFO] applying perturbations
# [2025-09-08 11:53:43 INFO] starting forward process for perturbed input
# [2025-09-08 11:53:44 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:44 INFO] variable SWout_Wm2 min: 0.000 mean: 81.830 max: 416.114 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] variable SWnet_Wm2 min: 83.348 mean: 640.705 max: 1089.000 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] variable Rn_Wm2 min: 35.352 mean: 505.063 max: 909.710 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] variable Rn_daylight_Wm2 min: 39.547 mean: 307.202 max: 488.100 nan: 0.00% (nan)
# [2025-09-08 11:53:44 INFO] Verma net radiation processing complete in 0.33 seconds
# [2025-09-08 11:53:44 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:44 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:44 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:44 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:45 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:45 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:45 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:45 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:45 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given field capacity
# [2025-09-08 11:53:45 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given wilting point
# [2025-09-08 11:53:45 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given canopy height
# [2025-09-08 11:53:45 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO
nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:45 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:45 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:45 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:45 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:45 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:45 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:45 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:45 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given field capacity
# [2025-09-08 11:53:45 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given wilting point
# [2025-09-08 11:53:45 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] using given canopy height
# [2025-09-08 11:53:45 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:45 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:45 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-09-08 11:53:45 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:45 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] started daylight ET upscaling
# [2025-09-08 11:53:45 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-09-08 11:53:45 INFO] PT-JPL-SM model run complete (elapsed: 0.03 seconds)
# [2025-09-08 11:53:45 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:45 INFO] forward process completed
# [2025-09-08 11:53:45 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-09-08 11:53:45 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-09-08 11:53:45 INFO] starting input perturbation generation
# [2025-09-08 11:53:45 INFO] input perturbation generation completed
# [2025-09-08 11:53:45 INFO] generating control group
# [2025-09-08 11:53:45 INFO] normalizing input perturbations
# [2025-09-08 11:53:45 INFO] applying perturbations
# [2025-09-08 11:53:45 INFO] starting forward process for perturbed input
# [2025-09-08 11:53:45 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:45 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LWin_Wm2 min: 169.079 mean: 349.064 max: 704.282 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:45 INFO] variable Rn_Wm2 min: 0.000 mean: 509.311 max: 994.574 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 310.010 max: 597.472 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] Verma net radiation processing complete in 0.31 seconds
# [2025-09-08 11:53:46 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:46 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:46 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:46 INFO] variable Ta_C min: -16.233 mean: 23.185 max: 63.464 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:46 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:46 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given field capacity
# [2025-09-08 11:53:46 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given wilting point
# [2025-09-08 11:53:46 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given canopy height
# [2025-09-08 11:53:46 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:46 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:46 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWin_Wm2 min: 169.079 mean: 349.064 max: 704.282 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_Wm2 min: 0.000 mean: 509.311 max: 994.574 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:46 INFO] variable Rn_Wm2 min: 0.000 mean: 509.311 max: 994.574 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:46 INFO] variable G min: 0.000 mean: 75.735 max: 248.000 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 0.100 mean: 24.164 max: 63.464 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable epsilon min: 0.179 mean: 0.704 max: 0.941 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 329.703 max: 812.006 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_soil_Wm2 min: 0.000 mean: 52.731 max: 497.712 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 179.608 max: 835.829 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable PET min: 0.000 mean: 392.601 max: 1028.979 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fTRM min: 0.047 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 122.032 max: 699.516 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_interception_Wm2 min: 0.000 mean: 6.719 max: 172.529 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_Wm2 min: 0.000 mean: 181.482 max: 922.534 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] started daylight ET upscaling
# [2025-09-08 11:53:46 INFO] variable Rn_daylight_Rn_Wm2 min: 0.000 mean: 310.010 max: 597.472 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable EF min: 0.000 mean: 0.396 max: 1.123 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_daylight_Wm2 min: 0.000 mean: 126.434 max: 615.690 nan: 0.00% (nan)
# /Users/halverso/Projects/PT-JPL-SM/PTJPLSM/model.py:490: RuntimeWarning: invalid value encountered in divide
#   EF = rt.where((LE_Wm2 == 0) | ((Rn_Wm2 - G_Wm2) == 0), 0, LE_Wm2 / (Rn_Wm2 - G_Wm2))
# [2025-09-08 11:53:46 INFO] variable ET_daylight_kg min: 0.000 mean: 2.493 max: 13.710 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] completed daylight ET upscaling (elapsed: 0.27 seconds)
# [2025-09-08 11:53:46 INFO] PT-JPL-SM model run complete (elapsed: 0.32 seconds)
# [2025-09-08 11:53:46 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:46 INFO] completed forward process for perturbed input
# [2025-09-08 11:53:46 INFO] normalizing output perturbations
# [2025-09-08 11:53:46 INFO] Monte Carlo run complete
# [2025-09-08 11:53:46 INFO] tarting Monte Carlo perturbed run
# [2025-09-08 11:53:46 INFO] calculating standard deviation of input variable: RH
# [2025-09-08 11:53:46 INFO] input variable RH standard deviation: 0.08657371001244944
# [2025-09-08 11:53:46 INFO] starting forward process
# [2025-09-08 11:53:46 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:46 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_daylight_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] Verma net radiation processing complete in 0.01 seconds
# [2025-09-08 11:53:46 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:46 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:46 INFO] starting PT-JPL-SM model run
# [2025-09-08 11:53:46 INFO] using given optimum temperature (Topt_C)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fAPARmax min: 0.233 mean: 0.361 max: 0.604 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given air temperature (Ta_C)
# [2025-09-08 11:53:46 INFO] variable Ta_C min: 1.853 mean: 23.189 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given relative humidity (RH)
# [2025-09-08 11:53:46 INFO] variable RH min: 0.273 mean: 0.384 max: 0.874 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given soil moisture (SM)
# [2025-09-08 11:53:46 INFO] variable soil_moisture min: 0.030 mean: 0.138 max: 0.664 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given field capacity
# [2025-09-08 11:53:46 INFO] variable field_capacity min: 0.190 mean: 0.272 max: 0.380 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given wilting point
# [2025-09-08 11:53:46 INFO] variable wilting_point min: 0.040 mean: 0.116 max: 0.160 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] using given canopy height
# [2025-09-08 11:53:46 INFO] variable canopy_height_meters min: 0.000 mean: 3.626 max: 25.743 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] running Verma net radiation with daylight upscaling
# [2025-09-08 11:53:46 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:46 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWin_Wm2 min: 227.974 mean: 345.157 max: 459.250 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] Verma net radiation processing complete in 0.00 seconds
# [2025-09-08 11:53:46 INFO] variable Rn_Wm2 min: 46.331 mean: 505.396 max: 804.181 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] calculating soil heat flux (G_Wm2)
# [2025-09-08 11:53:46 INFO] variable G min: 0.800 mean: 75.143 max: 191.438 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fwet min: 0.006 mean: 0.031 max: 0.583 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fREW min: 0.000 mean: 0.317 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 0.000 mean: 9.275 max: 20.450 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_soil_Wm2 min: 5.140 mean: 327.066 max: 664.535 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_soil_Wm2 min: 0.881 mean: 52.522 max: 329.161 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable Rn_canopy_Wm2 min: 18.954 mean: 178.330 max: 691.230 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable PET min: 34.197 mean: 390.024 max: 705.427 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable fTRM min: 0.147 mean: 0.833 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_canopy_Wm2 min: 5.421 mean: 122.330 max: 496.583 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_interception_Wm2 min: 0.119 mean: 6.646 max: 95.162 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_Wm2 min: 6.814 mean: 181.498 max: 590.508 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] started daylight ET upscaling
# [2025-09-08 11:53:46 INFO] variable Rn_daylight_Rn_Wm2 min: 51.830 mean: 307.445 max: 429.482 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable EF min: 0.036 mean: 0.404 max: 0.964 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable LE_daylight_Wm2 min: 5.033 mean: 126.264 max: 383.441 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] variable ET_daylight_kg min: 0.073 mean: 2.488 max: 8.184 nan: 0.00% (nan)
# [2025-09-08 11:53:46 INFO] completed daylight ET upscaling (elapsed: 0.01 seconds)
# [2025-09-08 11:53:46 INFO] PT-JPL-SM model run complete (elapsed: 0.05 seconds)
# [2025-09-08 11:53:46 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:46 INFO] forward process completed
# [2025-09-08 11:53:46 INFO] calculating standard deviation of output variable: ET_daylight_kg
# [2025-09-08 11:53:46 INFO] output variable ET_daylight_kg standard deviation: 1.887619260186298
# [2025-09-08 11:53:46 INFO] starting input perturbation generation
# [2025-09-08 11:53:46 INFO] input perturbation generation completed
# [2025-09-08 11:53:46 INFO] generating control group
# [2025-09-08 11:53:46 INFO] normalizing input perturbations
# [2025-09-08 11:53:46 INFO] applying perturbations
# [2025-09-08 11:53:46 INFO] starting forward process for perturbed input
# [2025-09-08 11:53:47 INFO] starting Verma net radiation processing
# [2025-09-08 11:53:47 INFO] variable SWout_Wm2 min: 3.988 mean: 81.498 max: 279.039 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable SWnet_Wm2 min: 94.327 mean: 641.038 max: 951.989 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LWin_Wm2 min: 220.117 mean: 344.576 max: 491.481 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LWout_Wm2 min: 316.593 mean: 480.800 max: 684.122 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable Rn_Wm2 min: 34.619 mean: 504.814 max: 822.011 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable Rn_daylight_Wm2 min: 38.727 mean: 307.085 max: 441.046 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] Verma net radiation processing complete in 0.30 seconds
# [2025-09-08 11:53:47 INFO] starting PT-JPL-SM table processing
# [2025-09-08 11:53:47 INFO] started extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:47 INFO] completed extracting geometry from PT-JPL-SM input table
# [2025-09-08 11:53:47 INFO] started extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:47 INFO] completed extracting time from PT-JPL-SM input table
# [2025-09-08 11:53:47 INFO] variable Topt_C min: 4.966 mean: 23.740 max: 38.909 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable epsilon min: 0.430 mean: 0.712 max: 0.849 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable Rn_soil_Wm2 min: 3.841 mean: 326.675 max: 686.644 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LE_soil_Wm2 min: 0.000 mean: 53.508 max: 343.179 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable Rn_canopy_Wm2 min: 15.958 mean: 178.139 max: 705.904 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable PET min: 25.553 mean: 389.571 max: 725.709 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable fTRM min: 0.019 mean: 0.821 max: 1.000 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 120.056 max: 515.278 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LE_interception_Wm2 min: 0.000 mean: 8.001 max: 280.528 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LE_Wm2 min: 5.710 mean: 181.565 max: 632.041 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] started daylight ET upscaling
# [2025-09-08 11:53:47 INFO] variable Rn_daylight_Rn_Wm2 min: 38.727 mean: 307.085 max: 441.046 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable EF min: 0.032 mean: 0.405 max: 0.967 nan: 0.00% (nan)
# [2025-09-08 11:53:47 INFO] variable LE_daylight_Wm2 min: 4.218 mean: 126.336 max: 391.035 nan: 0.00% (nan)
# [2025-09-08 11:53:48 INFO] variable ET_daylight_kg min: 0.061 mean: 2.489 max: 8.540 nan: 0.00% (nan)
# [2025-09-08 11:53:48 INFO] completed daylight ET upscaling (elapsed: 0.28 seconds)
# [2025-09-08 11:53:48 INFO] PT-JPL-SM model run complete (elapsed: 0.33 seconds)
# [2025-09-08 11:53:48 INFO] PT-JPL-SM table processing complete
# [2025-09-08 11:53:48 INFO] completed forward process for perturbed input
# [2025-09-08 11:53:48 INFO] normalizing output perturbations
# [2025-09-08 11:53:48 INFO] Monte Carlo run complete
#   input_variable output_variable                  metric     value
# 0           ST_C  ET_daylight_kg             correlation  0.687731
# 0           ST_C  ET_daylight_kg                      r2  0.472973
# 0           ST_C  ET_daylight_kg  mean_normalized_change  0.108439
# 0           NDVI  ET_daylight_kg             correlation  0.841875
# 0           NDVI  ET_daylight_kg                      r2  0.708753
# 0           NDVI  ET_daylight_kg  mean_normalized_change  0.521013
# 0         albedo  ET_daylight_kg             correlation  0.759157
# 0         albedo  ET_daylight_kg                      r2  0.576320
# 0         albedo  ET_daylight_kg  mean_normalized_change  0.048376
# 0           Ta_C  ET_daylight_kg             correlation  0.786090
# 0           Ta_C  ET_daylight_kg                      r2  0.617938
# 0           Ta_C  ET_daylight_kg  mean_normalized_change  0.198336
# 0             RH  ET_daylight_kg             correlation  0.439170
# 0             RH  ET_daylight_kg                      r2  0.192870
# 0             RH  ET_daylight_kg  mean_normalized_change  0.027118

# %% [markdown]
# ## Plot Sensitivity Magnitude Bar Chart
#
# This cell creates a bar chart showing the average percent change in latent heat flux for each input variable, visualizing the magnitude of model sensitivity to each input. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "ET_daylight_kg") & (df.metric == "mean_normalized_change")]
ax = sns.barplot(x=df.input_variable, y=df.value * 100, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
plt.xlabel("Input Variable")
plt.ylabel("Average Percent Change in Output Perturbation")
plt.title("PT-JPL-SM Evapotranspiration Sensitivity Magnitude")
# plt.ylim(0, 160)  # Set y-axis range from 0 to 160
plt.grid(axis='y', color='lightgray', linestyle='-', linewidth=0.5)  # Add light gray horizontal gridlines only

# Add percent sign to y-axis tick labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{int(y)}%'))

plt.savefig("PT-JPL-SM Evapotranspiration Sensitivity Magnitude.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL-SM Evapotranspiration Sensitivity Magnitude.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_72293/323368046.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Plot Sensitivity Correlation Bar Chart
#
# This cell generates a bar chart showing the correlation between input perturbations and output perturbations for each input variable, highlighting which inputs most strongly influence latent heat flux. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "ET_daylight_kg") & (df.metric == "correlation")]
ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
# plt.ylim(0, 0.8)
plt.xlabel("Input Variable")
plt.ylabel("Correlation of Input Perturbation to Output Perturbation")
plt.title("PT-JPL-SM Latent Heat Flux Sensitivity Correlation")
plt.grid(axis='y')  # Add horizontal gridlines

plt.savefig("PT-JPL-SM Latent Heat Flux Sensitivity Correlation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL-SM Latent Heat Flux Sensitivity Correlation.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_72293/2799509377.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Summary and Next Steps
#
# This notebook demonstrated a full sensitivity analysis workflow for the PT-JPL-SM model using ECOSTRESS Cal-Val data. Key results include the identification of input variables with the greatest influence on latent heat flux. Next steps could include further exploration of model parameters, additional visualizations, or application to other datasets.
